# %% [markdown]
# <a href="https://colab.research.google.com/github/dkopczyk/CIFAR10_ResNet_Crude/blob/main/Kopczyk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as dsets
import torchvision.transforms as transforms
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np
from sklearn.metrics import confusion_matrix

# %%
def update_lr(optimizer, lr):   # For updating the learning rate
    print(lr)
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
               
def logResults(epoch, num_epochs, train_loss, train_loss_history, test_loss, test_loss_history, epoch_counter, print_interval=1000):
  if (epoch%print_interval == 0):  print('Epoch [%d/%d], Train Loss: %.4f, Test Loss: %.4f' %(epoch+1, num_epochs, train_loss, test_loss))
  train_loss_history.append(train_loss)
  test_loss_history.append(test_loss)
  epoch_counter.append(epoch)

def graphLoss(epoch_counter, train_loss_hist, test_loss_hist, loss_name="Loss", start = 0):
  fig = plt.figure()
  plt.plot(epoch_counter[start:], train_loss_hist[start:], color='blue')
  plt.plot(epoch_counter[start:], test_loss_hist[start:], color='red')
  plt.legend(['Train Loss', 'Test Loss'], loc='upper right')
  plt.xlabel('#Epochs')
  plt.ylabel(loss_name)

def trainAndGraph(network, training_generator, testing_generator, loss_function, optimizer, num_epochs, learning_rate, logging_interval=1):
  #Arrays to store training history
  patience = 10
  test_loss_history = []
  epoch_counter = []
  train_loss_history = []
  amtTimes = 0
  last_loss = 999999
  best_loss = 999999
  for epoch in range(num_epochs):                           
    avg_loss = train(network, training_generator, loss_function, optimizer)
    test_loss = test(network, testing_generator, loss_function)
    logResults(epoch, num_epochs, avg_loss, train_loss_history, test_loss, test_loss_history, epoch_counter, logging_interval)
    if (test_loss > last_loss): 
      amtTimes += 1
    if (test_loss < best_loss):
      amtTimes = 0
      best_loss = test_loss
      torch.save(network.state_dict(), 'best_model.pt')
    last_loss = test_loss
    old_params = network.parameters()
    print("Amt times: ", amtTimes)
    if (amtTimes > patience):
      break
    if(amtTimes > 3):
    # if (epoch+1) % 5 == 0:
        print("updating lr")
        learning_rate /= 3
        update_lr(optimizer, learning_rate)
  
  graphLoss(epoch_counter, train_loss_history, test_loss_history)

# %%
use_cuda = torch.cuda.is_available()
print("Using GPU?:",use_cuda)
if (use_cuda):
  print("GPU Name:",torch.cuda.get_device_name())
  device = torch.device("cuda")
else:
  device = torch.device("cpu")
# Out:
# Using GPU?: True
# GPU Name: NVIDIA A100-SXM4-40GB

# %%
def train(network,  data_generator, loss_function, optimize, logging = 200):
  network.train() #updates any network layers that behave differently in training and execution 
  avg_loss = 0
  num_batches = 0
  for batch, (input_data, target_output) in enumerate(data_generator):
    input_data, target_output = input_data.to(device), target_output.to(device)
    optimizer.zero_grad()                            # Gradients need to be reset each batch
    prediction = network(input_data)                 # Forward pass: compute the output class given a image
    loss = loss_function(prediction, target_output)  # Compute the loss: difference between the output and correct result
    loss.backward()                                  # Backward pass: compute the gradients of the model with respect to the loss
    optimizer.step()
    avg_loss += loss.item()
    num_batches += 1
    if ((batch+1)%logging == 0): print('Batch [%d/%d], Train Loss: %.4f' %(batch+1, len(data_generator.dataset)/len(target_output), avg_loss/num_batches))
  return avg_loss/num_batches

def test(network, test_loader, loss_function):
  network.eval() #updates any network layers that behave differently in training and execution 
  test_loss = 0
  num_batches = 0
  with torch.no_grad(): 
    for data, target in test_loader:
      data, target = data.to(device), target.to(device)
      output = network(data)
      test_loss += loss_function(output, target).item()
      pred = output.data.max(1, keepdim=True)[1]
      num_batches += 1
  test_loss /= num_batches
  #print('\nTest set: Avg. loss: {:.4f})\n'.format(test_loss))
  return test_loss

def computeLabelAccuracy(networkModel, data_loader, label_text=""):
  test_loss = 0
  correct = 0
  networkModel.eval()
  with torch.no_grad():
    for data, target in data_loader:
      data, target = data.to(device), target.to(device)
      output = networkModel(data)
      pred = output.data.max(1, keepdim=True)[1]  #Check if the maximum/largest output class matches the label
      correct += pred.eq(target.data.view_as(pred)).sum()
  print('\n{}: Accuracy: {}/{} ({:.1f}%)'.format(
    label_text, correct, len(data_loader.dataset),
    100. * correct / len(data_loader.dataset)))
  
def drawPredictionsCIFAR10(networkModel, dataset, num_rows=6, num_cols = 10, skip_batches=0):
  #Plot some of the testing results 
  networkModel.eval()
  data_generator = torch.utils.data.DataLoader(testing_dataset, batch_size=num_rows*num_cols)
  data_enumerator = enumerate(data_generator)
  for i in range(skip_batches):  
     _, (images,labels) = next(data_enumerator) #skip a few batches if needed
  _, (images,labels) = next(data_enumerator)
  images, labels = images.to(device), labels.to(device)
  with torch.no_grad():
    pred_catigories = networkModel(images) #all 10 values
    pred_labels = pred_catigories.data.max(1, keepdim=True)[1] #only the highest value is the final prediction
  for row in range(num_rows):
    fig = plt.figure(figsize=(num_cols+6,5)) #adjust the plot size
    for i in range(num_cols):
      plt.subplot(1,num_cols,i+1)
      cur = i + row*num_cols
      #plt.tight_layout()
      drawColor = 'black'
      if pred_labels[cur].item() != labels[cur]:
        drawColor = 'red'
      img = images[cur] / 2 + 0.5     # unnormalize
      npimg = img.cpu().numpy()
      plt.imshow(np.transpose(npimg, (1, 2, 0)))  #, interpolation='none'
      plt.title(" O: {},\n L: {}".format(classes[pred_labels[cur].item()],classes[labels[cur]]), color=drawColor)
      plt.xticks([])
      plt.yticks([])

# %% [markdown]
# # **Get the Data**

# %%
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

image_w = 32
image_h = 32

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]) #RGB mean and std. dev

training_dataset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)

testing_dataset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)

# Define data transforms
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),                         #Random cropping
    transforms.RandomHorizontalFlip(),                            #Random flipping
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2), 
    # transforms.RandomAffine(degrees=10, translate=(0.05, 0.05), shear=None),  # Add random rotation
    transforms.RandomAffine(degrees=10, translate=(0.05, 0.05)),  #Random Rotation and translation
    transforms.ToTensor(),
    # transforms.Lambda(lambda x: add_gaussian_noise(x, mean=0.0, std=0.1)),  
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# Load CIFAR-10 data
training_dataset_augment = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
testing_dataset_augment = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
class Conv_block_batch_norm(nn.Module):
  def __init__(self, channels_in, channels_out):
      super().__init__()  
      ks = 3 #I'm lazy so this is hard-coded, but you should pass this parameter in at try 5x5 kernels
      self.conv = nn.Conv2d(channels_in, channels_out,kernel_size=ks, padding=1) #Passing = 1 -> no shrinking
      self.bn = nn.BatchNorm2d(channels_out)
  
  def forward(self, x):       # Forward pass which defines how the layers relate the input x to the output out
      x = self.conv(x)
      # x = F.relu(x)         # We could relu here, I'm not sure if it helps.
      x = self.bn(x)                               
      x = F.max_pool2d(x,kernel_size=2)
      x = F.relu(x)
      return x

# %%
class GaussianNoise(nn.Module):
  def __init__(self, sigma=0.1):
    super().__init__()
    self.sigma = sigma
    self.register_buffer('noise', torch.tensor(0))

  def forward(self, x):
    if self.training and self.sigma != 0: #If we are evaluating the network (not training) do nothing!
        scale = self.sigma * x.detach() #Detach so there is no gradient on sigma
        sampled_noise = self.noise.expand(*x.size()).float().normal_() * scale
        x = x + sampled_noise
    return x

# %% [markdown]
# TODO: Show the class distribution in the dataset

# %%
from os import X_OK
class Conv_residual_block(nn.Module):
  def __init__(self, channels_in_out): #in and out kernels must be the same size
      super().__init__()
      self.conv1 = nn.Conv2d(channels_in_out, channels_in_out, kernel_size=3, padding=1)
      self.bn1 = nn.BatchNorm2d(channels_in_out)
      self.gelu = nn.GELU()
      self.conv2 = nn.Conv2d(channels_in_out, channels_in_out, kernel_size=3, padding=1)
      self.bn2 = nn.BatchNorm2d(channels_in_out)
      self.gelu = nn.GELU()
      self.conv3 = nn.Conv2d(channels_in_out, channels_in_out, kernel_size=3, padding=1)
      self.bn3 = nn.BatchNorm2d(channels_in_out)
  
  def forward(self, x):  
      residual = x
      x = self.conv1(x)
      x = self.bn1(x)
      x = self.gelu(x)
      x = self.conv2(x)
      x = self.bn2(x)
      x = self.gelu(x)
      x = self.conv3(x)
      x = self.bn3(x)
      x = x + residual
      x = self.gelu(x)
      return x

# %%
class Conv_Res_Net_basic(nn.Module):
  def __init__(self, img_w, img_h, num_classes):
    super().__init__()  
    num_kernels1 = 16
    num_kernels2 = 32
    num_kernels3 = 64
    num_kernels4 = 128
    #-- Block 1
    self.conv_block1 = Conv_block_batch_norm(3,num_kernels1)     
    img_w = img_w//2 #Max pool shrinks size 2x
    img_h = img_h//2
    self.residual_block_1a = Conv_residual_block(num_kernels1)  #Kernel size does not change
    self.residual_block_1b = Conv_residual_block(num_kernels1)
    self.residual_block_1c = Conv_residual_block(num_kernels1)
    #-- Block 2
    self.conv_block2 = Conv_block_batch_norm(num_kernels1,num_kernels2)   
    img_w = img_w//2 #Max pool shrinks size 2x
    img_h = img_h//2
    self.residual_block_2a = Conv_residual_block(num_kernels2)  #Kernel size does not change
    self.residual_block_2b = Conv_residual_block(num_kernels2)
    self.residual_block_2c = Conv_residual_block(num_kernels2)
    #-- Block 3
    self.conv_block3 = Conv_block_batch_norm(num_kernels2,num_kernels3)  
    img_w = img_w//2 #Max pool shrinks size 2x
    img_h = img_h//2
    self.residual_block_3a = Conv_residual_block(num_kernels3)  #Kernel size does not change
    self.residual_block_3b = Conv_residual_block(num_kernels3)
    self.residual_block_3c = Conv_residual_block(num_kernels3)
    #-- Block 3
    self.conv_block4 = Conv_block_batch_norm(num_kernels3,num_kernels4)  
    img_w = img_w//2 #Max pool shrinks size 2x
    img_h = img_h//2
    self.residual_block_4a = Conv_residual_block(num_kernels4)  #Kernel size does not change
    self.residual_block_4b = Conv_residual_block(num_kernels4)
    self.residual_block_4c = Conv_residual_block(num_kernels4)
    #-- Classifier
    self.flattened_dim = (img_w*img_h) * num_kernels4
    self.linear = nn.Linear(self.flattened_dim, num_classes)
    self.noise = GaussianNoise(0.1)
  
  def forward(self, x):             # Forward pass which defines how the layers relate the input x to the output out
    #-- Block 1 --
    x = self.conv_block1(x)
    x = self.residual_block_1a(x)   # You can have as many of these fixed width blocks as you want in a row
    x = self.residual_block_1b(x)
    x = self.residual_block_1c(x)   
    #-- Block 2 --
    x = self.conv_block2(x)
    x = self.residual_block_2a(x)   # You can have as many of these fixed width blocks as you want in a row
    x = self.residual_block_2b(x)
    x = self.residual_block_2c(x)   
    #-- Block 3 --
    x = self.conv_block3(x)
    x = self.residual_block_3a(x)   # You can have as many of these fixed width blocks as you want in a row
    x = self.residual_block_3b(x)
    x = self.residual_block_3c(x)   
    #-- Block 4 --
    x = self.conv_block4(x)
    x = self.residual_block_4a(x)   # You can have as many of these fixed width blocks as you want in a row
    x = self.residual_block_4b(x)
    x = self.residual_block_4c(x)   
    #-- Linear Classifier --
    x = x.view(-1, self.flattened_dim)
    x = self.noise(x)  
    x = self.linear(x)
    x = self.noise(x) 
    
    return x

# %%
#Training parameters
num_epochs = 100
print_interval = 1
learning_rate = 0.01
batch_size = 100
weight_decay = 0.0001

#Create model
network = Conv_Res_Net_basic(image_w, image_h, 10)
network = network.to(device)

print("Num. Parameters:", count_parameters(network))

#Set optimizer and loss function
optimizer = torch.optim.Adam(network.parameters(), lr=learning_rate, weight_decay=weight_decay)
# optimizer = torch.optim.SGD(network.parameters(), lr=learning_rate, momentum=0.9)
# scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.1)
loss_function = nn.CrossEntropyLoss()

#Load the data, and split it into batches
training_generator = torch.utils.data.DataLoader(training_dataset, batch_size=batch_size, shuffle=True)
testing_generator = torch.utils.data.DataLoader(testing_dataset, batch_size=batch_size, shuffle=False)

print("Data is Loaded")

trainAndGraph(network, training_generator, testing_generator, loss_function, optimizer, num_epochs, learning_rate, print_interval)

print(learning_rate)
computeLabelAccuracy(network, training_generator, "Train Set")
computeLabelAccuracy(network, testing_generator, "Test Set")
drawPredictionsCIFAR10(network, testing_dataset, 7, 12, 0)
# Out:
# Num. Parameters: 1872090
# Data is Loaded
# Batch [200/500], Train Loss: 2.2873
# Batch [400/500], Train Loss: 2.0407
# Epoch [1/100], Train Loss: 1.9513, Test Loss: 1.5743
# Amt times:  0
# Batch [200/500], Train Loss: 1.4518
# Epoch [2/100], Train Loss: 1.3812, Test Loss: 1.5249
# Amt times:  0
# Batch [200/500], Train Loss: 1.1970
# Batch [400/500], Train Loss: 1.1498
# Epoch [3/100], Train Loss: 1.1321, Test Loss: 1.0915
# Amt times:  0
# Batch [200/500], Train Loss: 1.0660
# Batch [400/500], Train Loss: 1.0256
# Epoch [4/100], Train Loss: 1.0162, Test Loss: 0.9849
# Amt times:  0
# Batch [200/500], Train Loss: 0.9208
# Batch [400/500], Train Loss: 0.9029
# Epoch [5/100], Train Loss: 0.8933, Test Loss: 0.8543
# Amt times:  0
# Batch [200/500], Train Loss: 0.7915
# Batch [400/500], Train Loss: 0.8009
# Epoch [6/100], Train Loss: 0.8033, Test Loss: 0.9038
# Amt times:  1
# Batch [200/500], Train Loss: 0.7483
# Batch [400/500], Train Loss: 0.7591
# Epoch [7/100], Train Loss: 0.7579, Test Loss: 0.9134
# Amt times:  2
# Batch [200/500], Train Loss: 0.7138
# Batch [400/500], Train Loss: 0.7230
# Epoch [8/100], Train Loss: 0.7247, Test Loss: 0.7876
# Amt times:  0
# Batch [200/500], Train Loss: 0.6586
# Batch [400/500], Train Loss: 0.6828
# Epoch [9/100], Train Loss: 0.6886, Test Loss: 0.9440
# Amt times:  1
# Batch [200/500], Train Loss: 0.6459
# Batch [400/500], Train Loss: 0.6661
# Epoch [10/100], Train Loss: 0.6772, Test Loss: 0.8146
# Amt times:  1
# Batch [200/500], Train Loss: 0.6315
# Batch [400/500], Train Loss: 0.6436
# Epoch [11/100], Train Loss: 0.6538, Test Loss: 0.8069
# Amt times:  1
# Batch [200/500], Train Loss: 0.6152
# Batch [400/500], Train Loss: 0.6359
# Epoch [12/100], Train Loss: 0.6397, Test Loss: 0.7806
# Amt times:  0
# Batch [200/500], Train Loss: 0.5840
# Batch [400/500], Train Loss: 0.6091
# Epoch [13/100], Train Loss: 0.6150, Test Loss: 1.3946
# Amt times:  1
# Batch [200/500], Train Loss: 0.5728
# Batch [400/500], Train Loss: 0.5995
# Epoch [14/100], Train Loss: 0.6033, Test Loss: 0.7984
# Amt times:  1
# Batch [200/500], Train Loss: 0.5707
# Batch [400/500], Train Loss: 0.5925
# Epoch [15/100], Train Loss: 0.5998, Test Loss: 0.8613
# Amt times:  2
# Batch [200/500], Train Loss: 0.5646
# Batch [400/500], Train Loss: 0.5882
# Epoch [16/100], Train Loss: 0.5926, Test Loss: 0.9613
# Amt times:  3
# Batch [200/500], Train Loss: 0.5610
# Batch [400/500], Train Loss: 0.5781
# Epoch [17/100], Train Loss: 0.5888, Test Loss: 0.7591
# Amt times:  0
# Batch [200/500], Train Loss: 0.5341
# Batch [400/500], Train Loss: 0.5644
# Epoch [18/100], Train Loss: 0.5725, Test Loss: 0.7812
# Amt times:  1
# Batch [200/500], Train Loss: 0.5266
# Batch [400/500], Train Loss: 0.5552
# Epoch [19/100], Train Loss: 0.5660, Test Loss: 0.8593
# Amt times:  2
# Batch [200/500], Train Loss: 0.5384
# Batch [400/500], Train Loss: 0.5574
# Epoch [20/100], Train Loss: 0.5636, Test Loss: 0.7216
# Amt times:  0
# Batch [200/500], Train Loss: 0.5202
# Batch [400/500], Train Loss: 0.5427
# Epoch [21/100], Train Loss: 0.5533, Test Loss: 0.7956
# Amt times:  1
# Batch [200/500], Train Loss: 0.5169
# Batch [400/500], Train Loss: 0.5433
# Epoch [22/100], Train Loss: 0.5490, Test Loss: 0.8345
# Amt times:  2
# Batch [200/500], Train Loss: 0.5181
# Batch [400/500], Train Loss: 0.5361
# Epoch [23/100], Train Loss: 0.5417, Test Loss: 0.7537
# Amt times:  2
# Batch [200/500], Train Loss: 0.5060
# Batch [400/500], Train Loss: 0.5317
# Epoch [24/100], Train Loss: 0.5420, Test Loss: 0.8144
# Amt times:  3
# Batch [200/500], Train Loss: 0.4939
# Batch [400/500], Train Loss: 0.5282
# Epoch [25/100], Train Loss: 0.5356, Test Loss: 0.8701
# Amt times:  4
# updating lr
# 0.0033333333333333335
# Batch [200/500], Train Loss: 0.3783
# Batch [400/500], Train Loss: 0.3738
# Epoch [26/100], Train Loss: 0.3677, Test Loss: 0.6440
# Amt times:  0
# Batch [200/500], Train Loss: 0.2865
# Batch [400/500], Train Loss: 0.3071
# Epoch [27/100], Train Loss: 0.3112, Test Loss: 0.6999
# Amt times:  1
# Batch [200/500], Train Loss: 0.2684
# Batch [400/500], Train Loss: 0.2833
# Epoch [28/100], Train Loss: 0.2915, Test Loss: 0.7963
# Amt times:  2
# Batch [200/500], Train Loss: 0.2479
# Batch [400/500], Train Loss: 0.2691
# Epoch [29/100], Train Loss: 0.2790, Test Loss: 0.7727
# Amt times:  2
# Batch [200/500], Train Loss: 0.2339
# Batch [400/500], Train Loss: 0.2521
# Epoch [30/100], Train Loss: 0.2643, Test Loss: 0.7473
# Amt times:  2
# Batch [200/500], Train Loss: 0.2160
# Batch [400/500], Train Loss: 0.2439
# Epoch [31/100], Train Loss: 0.2566, Test Loss: 0.8311
# Amt times:  3
# Batch [200/500], Train Loss: 0.2182
# Batch [400/500], Train Loss: 0.2394
# Epoch [32/100], Train Loss: 0.2457, Test Loss: 0.8258
# Amt times:  3
# Batch [200/500], Train Loss: 0.2080
# Batch [400/500], Train Loss: 0.2297
# Epoch [33/100], Train Loss: 0.2383, Test Loss: 0.8417
# Amt times:  4
# updating lr
# 0.0011111111111111111
# Batch [200/500], Train Loss: 0.1531
# Batch [400/500], Train Loss: 0.1464
# Epoch [34/100], Train Loss: 0.1452, Test Loss: 0.8504
# Amt times:  5
# updating lr
# 0.00037037037037037035
# Batch [200/500], Train Loss: 0.0974
# Batch [400/500], Train Loss: 0.0951
# Epoch [35/100], Train Loss: 0.0954, Test Loss: 0.8471
# Amt times:  5
# updating lr
# 0.0001234567901234568
# Batch [200/500], Train Loss: 0.0828
# Batch [400/500], Train Loss: 0.0809
# Epoch [36/100], Train Loss: 0.0806, Test Loss: 0.8567
# Amt times:  6
# updating lr
# 4.11522633744856e-05
# Batch [200/500], Train Loss: 0.0749
# Batch [400/500], Train Loss: 0.0760
# Epoch [37/100], Train Loss: 0.0767, Test Loss: 0.8590
# Amt times:  7
# updating lr
# 1.3717421124828534e-05
# Batch [200/500], Train Loss: 0.0755
# Batch [400/500], Train Loss: 0.0744
# Epoch [38/100], Train Loss: 0.0741, Test Loss: 0.8574
# Amt times:  7
# updating lr
# 4.572473708276178e-06
# Batch [200/500], Train Loss: 0.0752
# Batch [400/500], Train Loss: 0.0738
# Epoch [39/100], Train Loss: 0.0748, Test Loss: 0.8671
# Amt times:  8
# updating lr
# 1.524157902758726e-06
# Batch [200/500], Train Loss: 0.0768
# Batch [400/500], Train Loss: 0.0755
# Epoch [40/100], Train Loss: 0.0754, Test Loss: 0.8613
# Amt times:  8
# updating lr
# 5.080526342529087e-07
# Batch [200/500], Train Loss: 0.0726
# Batch [400/500], Train Loss: 0.0737
# Epoch [41/100], Train Loss: 0.0742, Test Loss: 0.8604
# Amt times:  8
# updating lr
# 1.6935087808430289e-07
# Batch [200/500], Train Loss: 0.0745
# Batch [400/500], Train Loss: 0.0733
# Epoch [42/100], Train Loss: 0.0737, Test Loss: 0.8598
# Amt times:  8
# updating lr
# 5.645029269476763e-08
# Batch [200/500], Train Loss: 0.0773
# Batch [400/500], Train Loss: 0.0756
# Epoch [43/100], Train Loss: 0.0751, Test Loss: 0.8633
# Amt times:  9
# updating lr
# 1.881676423158921e-08
# Batch [200/500], Train Loss: 0.0748
# Batch [400/500], Train Loss: 0.0747
# Epoch [44/100], Train Loss: 0.0740, Test Loss: 0.8599
# Amt times:  9
# updating lr
# 6.27225474386307e-09
# Batch [200/500], Train Loss: 0.0733
# Batch [400/500], Train Loss: 0.0738
# Epoch [45/100], Train Loss: 0.0749, Test Loss: 0.8601
# Amt times:  10
# updating lr
# 2.09075158128769e-09
# Batch [200/500], Train Loss: 0.0740
# Batch [400/500], Train Loss: 0.0750
# Epoch [46/100], Train Loss: 0.0753, Test Loss: 0.8641
# Amt times:  11
# 0.01
#
# Train Set: Accuracy: 49556/50000 (99.1%)
#
# Test Set: Accuracy: 8019/10000 (80.2%)

# %% [markdown]
# # **REFACTOR ATTEMPT**
